# %%
# import tensorflow and numpy
import tensorflow as tf
import numpy as np

# %%
# restore checkpoint and make predition

save_file = './favorr_05.ckpt'

# init graph
tf.reset_default_graph()

# test_features = np.array([[ 0.09346868, -0.08672126,  1.        ,  1.        ,  0.        ]])
test_features = np.array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          5.40000000e+01,   1.96505500e+06],
       [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   6.96980000e+05],
       [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          1.05100000e+03,   8.00594000e+05],
       [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   2.45478300e+06],
       [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
          0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
          5.57000000e+02,   1.63726600e+06]], dtype=np.float32)

# print(test_features)



# number of features and lables
features_count = 14
labels_count = 2

# feature ad labesls
features = tf.placeholder(tf.float32, [None, features_count], name="x")
labels = tf.placeholder(tf.float32, [None, labels_count], name="y")

# Set the weights and biases tensors
layer_1_count = 8
layer_2_count = 6

# USE truncated_normal! this is important!!!

weights_1 = tf.Variable(tf.truncated_normal([features_count,
                                             layer_1_count],
                                             mean=0.0,
                                             stddev=0.1), name='weights_1')
biases_1 = tf.Variable(tf.truncated_normal([layer_1_count],
                                           mean=0.0,
                                           stddev=0.1), name='biases_1')

weights_2 = tf.Variable(tf.truncated_normal([layer_1_count,
                                             layer_2_count],
                                             mean=0.0,
                                             stddev=0.1), name='weights_2')
biases_2 = tf.Variable(tf.truncated_normal([layer_2_count],
                                           mean=0.0,
                                           stddev=0.1), name='biases_2')


weights_3 = tf.Variable(tf.truncated_normal([layer_2_count,
                                             labels_count],
                                             mean=0.0,
                                             stddev=0.1), name='weights_3')
biases_3 = tf.Variable(tf.truncated_normal([labels_count],
                                           mean=0.0,
                                           stddev=0.1), name='biases_3')
keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# # Feed dicts for training, validation, and test session
# train_feed_dict = {features: train_features, labels: train_labels, keep_prob:0.75}
# valid_feed_dict = {features: valid_features, labels: valid_labels, keep_prob:0.75}
# test_feed_dict = {features: test_features, labels: test_labels, keep_prob:0.75}

# tensorflow gragh

# layer 1
output_1 = tf.add(tf.matmul(features, weights_1) , biases_1)
output_1 = tf.nn.relu(output_1)

# layer 2
output_2 = tf.add(tf.matmul(output_1, weights_2) , biases_2)
output_2 = tf.nn.relu(output_2)

# output layer
output_3 = tf.add(tf.matmul(output_2, weights_3) , biases_3)

# dropout
output_3_1 = tf.nn.dropout(output_3, keep_prob)

# prediction
prediction = tf.nn.softmax(output_3)

test_feed_dict = {features: test_features, labels: np.array([[]]), keep_prob:1.0}

# Test Cases
with tf.Session() as sess:
    saver.restore(sess, save_file)
    print(sess.run(prediction, feed_dict={features:test_features}))

print('How!!!')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     918             subfeed_t = self.graph.as_graph_element(subfeed, allow_tensor=True,
# --> 919                                                     allow_operation=False)
#     920           except Exception as e:
#
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    2472     with self._lock:
# -> 2473       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2474
#
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    2514                          "exist. The operation, %s, does not exist in the "
# -> 2515                          "graph." % (repr(name), repr(op_name)))
#    2516         try:
#
# KeyError: "The name 'save/Const:0' refers to a Tensor which does not exist. The operation, 'save/Const', does not exist in the graph."
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-21d571c8df6b> in <module>()
#     104 # Test Cases
#     105 with tf.Session() as sess:
# --> 106     saver.restore(sess, save_file)
#     107     print(sess.run(prediction, feed_dict={features:test_features}))
#     108
#
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/kouohhashi/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     920           except Exception as e:
#     921             raise TypeError('Cannot interpret feed_dict key as Tensor: '
# --> 922                             + e.args[0])
#     923
#     924           if isinstance(subfeed_val, ops.Tensor):
#
# TypeError: Cannot interpret feed_dict key as Tensor: The name 'save/Const:0' refers to a Tensor which does not exist. The operation, 'save/Const', does not exist in the graph.
